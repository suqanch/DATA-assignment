# %% [markdown]
# ###  population

# %%
#loading all library
library(tidyverse)
library(readr)
library(knitr)
library(skimr)
# Out:
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.4     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   2.0.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
change_rate <- read.csv(file="change rate.csv", show_col_types = FALSE)
#population <- read.csv(file="population1.csv", show_col_types = FALSE)
migrant <- read.csv(file="migrant1.csv", show_col_types = FALSE)
# Out:
# New names:
# * `` -> ...2
# * `` -> ...3
# * `` -> ...4
# * `` -> ...5
#
# New names:
# * `` -> ...2
# * `` -> ...3
# * `` -> ...4
# * `` -> ...5
# * `` -> ...6
# * ...

# %%
#population clean up
population <- read.csv(file="population1.csv", skip = 1)
population <- population %>% slice(4, 8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48, 52, 56, 60, 64)
write.csv(population, file = "population_1.csv")

# %%
#change_rate clean up
change_rate <- read.csv(file="change rate.csv", skip = 1)
change_rate <- change_rate %>% rename(year = X, Population_change = Population.change)
change_rate <- change_rate %>% slice(1:16)
change_rate
write.csv(change_rate, file = "change_rate_1.csv")
# Out:
#    year Population_change Percent.population.change Natural.increase
# 1  2005  46600            1.13                      31000
# 2  2006  48200            1.16                      31600
# 3  2007  36600            0.87                      35800
# 4  2008  34500            0.81                      35400
# 5  2009  51900            1.21                      35300
# 6  2010  41700            0.96                      36000
# 7  2011  25600            0.58                      32100
# 8  2012  26400            0.60                      32300
# 9  2013  51500            1.16                      29800
# 10 2014  87000            1.94                      27800
# 11 2015  99400            2.18                      27800
# 12 2016 103900            2.23                      29300
# 13 2017  91900            1.93                      27200
# 14 2018  81800            1.68                      26500
# 15 2019  99200            2.01                      26600
# 16 2020  66000            1.31                      26500
#    Net.migration
# 1   7000
# 2  14600
# 3   5500
# 4   3800
# 5  21300
# 6  10500
# 7  -1900
# 8  -1200
# 9  18200
# 10 47400
# 11 59800
# 12 62900
# 13 53300
# 14 49600
# 15 72600
# 16 39600

# %%
migrant <- read.csv(file="migrant1.csv", skip = 5)
migrant <- migrant[,-7]
migrant
# Out:
#    X.
# 1  2005
# 2  2006
# 3  2007
# 4  2008
# 5  2009
# 6  2010
# 7  2011
# 8  2012
# 9  2013
# 10 2014
# 11 2015
# 12 2016
# 13 2017
# 14 2018
# 15 2019
# 16 2020
# 17 Table information:
# 18 Units:
# 19 Number, Magnitude = Units
# 20 Footnotes:
# 21 The standard error indicates the uncertainty of the provisional migration estimate. For example, the 95 percent confidence interval is +/-1.96 standard errors.
# 22 These intervals reflect the model uncertainty, not the extent of future revisions to provisional data. Standard errors are non-additive.
# 23 Owing to rounding, individual figures may not sum to stated totals.
# 24 Visa type is available from July 2003
# 25 The immigration visa type is that held or granted on arrival in New Zealand. People may change their visa type while still in New Zealand.
# 26
# 27 Symbols:
# 28 .. figure not available
# 29 C: Confidential
# 30 E: Early Estimate
# 31 P: Provisional
# 32 R: Revised
# 33 S: Suppressed
# 34 Status flags are not displayed
# 35 Table reference:
# 36 ITM492AA
# 37 Last updated:
# 38 10 September 2021 10:45am
# 39 Source: Statistics New Zealand
# 40 Contact: Information Centre
# 41 Telephone: 0508 525 525
# 42 Email:info@stats.govt.nz
#    Estimate Estimate.1 Estimate.2 Estimate.3 Estimate.4 Estimate.6
# 1  18457     8058      28609      11221      36478      103982
# 2  19367     9534      30498      13882      36177      110687
# 3  16758    12563      32118      15900      34982      113450
# 4  15965    16214      33620      17451      35237      119994
# 5  14818    16114      23731      14731      37349      108265
# 6  13535    17015      19840      13406      35613      100499
# 7  13784    16774      19689      15603      33261      100206
# 8  13852    16145      18092      17705      34685      101762
# 9  13508    16444      18102      20317      40520      110282
# 10 14511    25323      21269      22026      43572      128180
# 11 14982    30062      23545      24926      45165      140125
# 12 17161    25866      26814      26111      45996      143124
# 13 15601    25210      25516      29183      43513      140102
# 14 13268    24664      26843      31866      41344      139016
# 15 14499    26744      32992      39742      48461      165742
# 16  7490    10565      16199      12968      37887       88768
# 17    NA       NA         NA         NA         NA          NA
# 18    NA       NA         NA         NA         NA          NA
# 19    NA       NA         NA         NA         NA          NA
# 20    NA       NA         NA         NA         NA          NA
# 21    NA       NA         NA         NA         NA          NA
# 22    NA       NA         NA         NA         NA          NA
# 23    NA       NA         NA         NA         NA          NA
# 24    NA       NA         NA         NA         NA          NA
# 25    NA       NA         NA         NA         NA          NA
# 26    NA       NA         NA         NA         NA          NA
# 27    NA       NA         NA         NA         NA          NA
# 28    NA       NA         NA         NA         NA          NA
# 29    NA       NA         NA         NA         NA          NA
# 30    NA       NA         NA         NA         NA          NA
# 31    NA       NA         NA         NA         NA          NA
# 32    NA       NA         NA         NA         NA          NA
# 33    NA       NA         NA         NA         NA          NA
# 34    NA       NA         NA         NA         NA          NA
# 35    NA       NA         NA         NA         NA          NA
# 36    NA       NA         NA         NA         NA          NA
# 37    NA       NA         NA         NA         NA          NA
# 38    NA       NA         NA         NA         NA          NA
# 39    NA       NA         NA         NA         NA          NA
# 40    NA       NA         NA         NA         NA          NA
# 41    NA       NA         NA         NA         NA          NA
# 42    NA       NA         NA         NA         NA          NA

# %%
migrant <- read.csv(file="migrant1.csv", skip = 5)
migrant <- migrant[,-7]
migrant <- migrant %>% rename(year = X., Residence_Permanent_Residence = Estimate,
                             Student_Permanent_Residence= Estimate.1,
                             Visitor_Permanent_Residence = Estimate.2,
                             Work_Permanent_Residence = Estimate.3,
                             New_Zealand_and_Australian_citizens = Estimate.4,
                             TOTAL = Estimate.6)
migrant <- migrant %>% slice(1:16)
write.csv(migrant, file = "migrant_1.csv")

# %%
migrant
change_rate
population
# Out:
#    year Residence_Permanent_Residence Student_Permanent_Residence
# 1  2005 18457                          8058
# 2  2006 19367                          9534
# 3  2007 16758                         12563
# 4  2008 15965                         16214
# 5  2009 14818                         16114
# 6  2010 13535                         17015
# 7  2011 13784                         16774
# 8  2012 13852                         16145
# 9  2013 13508                         16444
# 10 2014 14511                         25323
# 11 2015 14982                         30062
# 12 2016 17161                         25866
# 13 2017 15601                         25210
# 14 2018 13268                         24664
# 15 2019 14499                         26744
# 16 2020  7490                         10565
#    Visitor_Permanent_Residence Work_Permanent_Residence
# 1  28609                       11221
# 2  30498                       13882
# 3  32118                       15900
# 4  33620                       17451
# 5  23731                       14731
# 6  19840                       13406
# 7  19689                       15603
# 8  18092                       17705
# 9  18102                       20317
# 10 21269                       22026
# 11 23545                       24926
# 12 26814                       26111
# 13 25516                       29183
# 14 26843                       31866
# 15 32992                       39742
# 16 16199                       12968
#    New_Zealand_and_Australian_citizens TOTAL
# 1  36478                               103982
# 2  36177                               110687
# 3  34982                               113450
# 4  35237                               119994
# 5  37349                               108265
# 6  35613                               100499
# 7  33261                               100206
# 8  34685                               101762
# 9  40520                               110282
# 10 43572                               128180
# 11 45165                               140125
# 12 45996                               143124
# 13 43513                               140102
# 14 41344                               139016
# 15 48461                               165742
# 16 37887                                88768
#    year Population_change Percent.population.change Natural.increase
# 1  2005  46600            1.13                      31000
# 2  2006  48200            1.16                      31600
# 3  2007  36600            0.87                      35800
# 4  2008  34500            0.81                      35400
# 5  2009  51900            1.21                      35300
# 6  2010  41700            0.96                      36000
# 7  2011  25600            0.58                      32100
# 8  2012  26400            0.60                      32300
# 9  2013  51500            1.16                      29800
# 10 2014  87000            1.94                      27800
# 11 2015  99400            2.18                      27800
# 12 2016 103900            2.23                      29300
# 13 2017  91900            1.93                      27200
# 14 2018  81800            1.68                      26500
# 15 2019  99200            2.01                      26600
# 16 2020  66000            1.31                      26500
#    Net.migration
# 1   7000
# 2  14600
# 3   5500
# 4   3800
# 5  21300
# 6  10500
# 7  -1900
# 8  -1200
# 9  18200
# 10 47400
# 11 59800
# 12 62900
# 13 53300
# 14 49600
# 15 72600
# 16 39600
#    year   Total
# 1  2005Q4 4153500
# 2  2006Q4 4202300
# 3  2007Q4 4240000
# 4  2008Q4 4274900
# 5  2009Q4 4324700
# 6  2010Q4 4368300
# 7  2011Q4 4395700
# 8  2012Q4 4420700
# 9  2013Q4 4467600
# 10 2014Q4 4552300
# 11 2015Q4 4650000
# 12 2016Q4 4754400
# 13 2017Q4 4847900
# 14 2018Q4 4931300
# 15 2019Q4 5023700
# 16 2020Q4 5102900

# %%
population <- population %>% mutate(year = c(2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016, 2017,2018,2019,2020))
population_change_rate <- merge(population, change_rate)
population_change_rate <- population_change_rate %>% rename(total_population = Total)

# %%
write.csv(population_change_rate, file = "population_change_rate.csv")

# %%
region_population <- read.csv(file="region population.csv", skip = 1)
region_population
# Out:
#    X
# 1  2005
# 2  2006
# 3  2007
# 4  2008
# 5  2009
# 6  2010
# 7  2011
# 8  2012
# 9  2013
# 10 2014
# 11 2015
# 12 2016
# 13 2017
# 14 2018
# 15 2019
# 16 2020
# 17 Table information:
# 18 Units:
# 19 Number, Magnitude = Units
# 20 Footnotes:
# 21 New Zealand comprises the North Island and South Island regions plus areas not included in a region (eg Chatham Islands Territory).
# 22 Population estimates after 30 June 2013 have been revised to incorporate results from the 2018 Census and 2018 Post-enumeration survey.
# 23 All population estimates at 30 June 2018 and beyond use the 2018-base ERP.
# 24 Estimates flagged as provisional are subject to revision, mainly to incorporate revisions to external (international) migration estimates.
# 25 Boundaries at 1 January 2020.
# 26
# 27 Symbols:
# 28 .. figure not available
# 29 C: Confidential
# 30 E: Early Estimate
# 31 P: Provisional
# 32 R: Revised
# 33 S: Suppressed
# 34 Status flags are not displayed
# 35 Table reference:
# 36 DPE051AA
# 37 Last updated:
# 38 22 October 2020 10:45am
# 39 Source: Statistics New Zealand
# 40 Contact: Information Centre
# 41 Telephone: 0508 525 525
# 42 Email:info@stats.govt.nz
#    Northland.Region Auckland.Region Wellington.Region Marlborough.Region
# 1  151000           1348900         461600            43000
# 2  152700           1373000         466300            43600
# 3  154700           1390400         469300            43800
# 4  156300           1405500         471800            44200
# 5  158200           1421700         475600            44400
# 6  160600           1439600         479400            44600
# 7  162500           1459600         483400            44700
# 8  163500           1476500         485100            44600
# 9  164700           1493200         486700            44700
# 10 168200           1520400         493800            45400
# 11 172100           1552800         501800            46200
# 12 176400           1589800         510700            47100
# 13 181200           1625100         518300            47900
# 14 185800           1654800         525900            48700
# 15 189600           1680500         532600            49400
# 16 194600           1717500         542000            50200
# 17     NA                NA             NA               NA
# 18     NA                NA             NA               NA
# 19     NA                NA             NA               NA
# 20     NA                NA             NA               NA
# 21     NA                NA             NA               NA
# 22     NA                NA             NA               NA
# 23     NA                NA             NA               NA
# 24     NA                NA             NA               NA
# 25     NA                NA             NA               NA
# 26     NA                NA             NA               NA
# 27     NA                NA             NA               NA
# 28     NA                NA             NA               NA
# 29     NA                NA             NA               NA
# 30     NA                NA             NA               NA
# 31     NA                NA             NA               NA
# 32     NA                NA             NA               NA
# 33     NA                NA             NA               NA
# 34     NA                NA             NA               NA
# 35     NA                NA             NA               NA
# 36     NA                NA             NA               NA
# 37     NA                NA             NA               NA
# 38     NA                NA             NA               NA
# 39     NA                NA             NA               NA
# 40     NA                NA             NA               NA
# 41     NA                NA             NA               NA
# 42     NA                NA             NA               NA
#    Canterbury.Region North.Island
# 1  531900            3145400
# 2  540000            3185100
# 3  547400            3214700
# 4  553800            3241700
# 5  560600            3274500
# 6  567700            3311700
# 7  559300            3348100
# 8  556000            3373700
# 9  562900            3398700
# 10 570600            3458300
# 11 585600            3527700
# 12 601900            3606300
# 13 614300            3684400
# 14 622800            3753700
# 15 632300            3814800
# 16 645900            3896200
# 17     NA                 NA
# 18     NA                 NA
# 19     NA                 NA
# 20     NA                 NA
# 21     NA                 NA
# 22     NA                 NA
# 23     NA                 NA
# 24     NA                 NA
# 25     NA                 NA
# 26     NA                 NA
# 27     NA                 NA
# 28     NA                 NA
# 29     NA                 NA
# 30     NA                 NA
# 31     NA                 NA
# 32     NA                 NA
# 33     NA                 NA
# 34     NA                 NA
# 35     NA                 NA
# 36     NA                 NA
# 37     NA                 NA
# 38     NA                 NA
# 39     NA                 NA
# 40     NA                 NA
# 41     NA                 NA
# 42     NA                 NA

# %%
region_population <- region_population %>% rename(year = x)
# Out:
#    year
# 1  2005
# 2  2006
# 3  2007
# 4  2008
# 5  2009
# 6  2010
# 7  2011
# 8  2012
# 9  2013
# 10 2014
# 11 2015
# 12 2016
# 13 2017
# 14 2018
# 15 2019
# 16 2020
# 17 Table information:
# 18 Units:
# 19 Number, Magnitude = Units
# 20 Footnotes:
# 21 New Zealand comprises the North Island and South Island regions plus areas not included in a region (eg Chatham Islands Territory).
# 22 Population estimates after 30 June 2013 have been revised to incorporate results from the 2018 Census and 2018 Post-enumeration survey.
# 23 All population estimates at 30 June 2018 and beyond use the 2018-base ERP.
# 24 Estimates flagged as provisional are subject to revision, mainly to incorporate revisions to external (international) migration estimates.
# 25 Boundaries at 1 January 2020.
# 26
# 27 Symbols:
# 28 .. figure not available
# 29 C: Confidential
# 30 E: Early Estimate
# 31 P: Provisional
# 32 R: Revised
# 33 S: Suppressed
# 34 Status flags are not displayed
# 35 Table reference:
# 36 DPE051AA
# 37 Last updated:
# 38 22 October 2020 10:45am
# 39 Source: Statistics New Zealand
# 40 Contact: Information Centre
# 41 Telephone: 0508 525 525
# 42 Email:info@stats.govt.nz
#    Northland.Region Auckland.Region Wellington.Region Marlborough.Region
# 1  151000           1348900         461600            43000
# 2  152700           1373000         466300            43600
# 3  154700           1390400         469300            43800
# 4  156300           1405500         471800            44200
# 5  158200           1421700         475600            44400
# 6  160600           1439600         479400            44600
# 7  162500           1459600         483400            44700
# 8  163500           1476500         485100            44600
# 9  164700           1493200         486700            44700
# 10 168200           1520400         493800            45400
# 11 172100           1552800         501800            46200
# 12 176400           1589800         510700            47100
# 13 181200           1625100         518300            47900
# 14 185800           1654800         525900            48700
# 15 189600           1680500         532600            49400
# 16 194600           1717500         542000            50200
# 17     NA                NA             NA               NA
# 18     NA                NA             NA               NA
# 19     NA                NA             NA               NA
# 20     NA                NA             NA               NA
# 21     NA                NA             NA               NA
# 22     NA                NA             NA               NA
# 23     NA                NA             NA               NA
# 24     NA                NA             NA               NA
# 25     NA                NA             NA               NA
# 26     NA                NA             NA               NA
# 27     NA                NA             NA               NA
# 28     NA                NA             NA               NA
# 29     NA                NA             NA               NA
# 30     NA                NA             NA               NA
# 31     NA                NA             NA               NA
# 32     NA                NA             NA               NA
# 33     NA                NA             NA               NA
# 34     NA                NA             NA               NA
# 35     NA                NA             NA               NA
# 36     NA                NA             NA               NA
# 37     NA                NA             NA               NA
# 38     NA                NA             NA               NA
# 39     NA                NA             NA               NA
# 40     NA                NA             NA               NA
# 41     NA                NA             NA               NA
# 42     NA                NA             NA               NA
#    Canterbury.Region North.Island
# 1  531900            3145400
# 2  540000            3185100
# 3  547400            3214700
# 4  553800            3241700
# 5  560600            3274500
# 6  567700            3311700
# 7  559300            3348100
# 8  556000            3373700
# 9  562900            3398700
# 10 570600            3458300
# 11 585600            3527700
# 12 601900            3606300
# 13 614300            3684400
# 14 622800            3753700
# 15 632300            3814800
# 16 645900            3896200
# 17     NA                 NA
# 18     NA                 NA
# 19     NA                 NA
# 20     NA                 NA
# 21     NA                 NA
# 22     NA                 NA
# 23     NA                 NA
# 24     NA                 NA
# 25     NA                 NA
# 26     NA                 NA
# 27     NA                 NA
# 28     NA                 NA
# 29     NA                 NA
# 30     NA                 NA
# 31     NA                 NA
# 32     NA                 NA
# 33     NA                 NA
# 34     NA                 NA
# 35     NA                 NA
# 36     NA                 NA
# 37     NA                 NA
# 38     NA                 NA
# 39     NA                 NA
# 40     NA                 NA
# 41     NA                 NA
# 42     NA                 NA

# %%
region_population <- region_population %>% slice(1:16)
write.csv(region_population, file = "region_population.csv")
