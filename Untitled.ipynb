# %%
library(tidyverse)
library(readr)
library(knitr)
library(skimr)

# %%
Resident <- read.csv(file = "Estimat Resident Population .csv") #read csv

# %%
Resident
# Out:
#     Estimated.Resident.Population..Mean.Quarter.Ended..by.Sex..1991....Qrtly.Mar.Jun.Sep.Dec.
# 1
# 2   1991Q1
# 3   1991Q2
# 4   1991Q3
# 5   1991Q4
# 6   1992Q1
# 7   1992Q2
# 8   1992Q3
# 9   1992Q4
# 10  1993Q1
# 11  1993Q2
# 12  1993Q3
# 13  1993Q4
# 14  1994Q1
# 15  1994Q2
# 16  1994Q3
# 17  1994Q4
# 18  1995Q1
# 19  1995Q2
# 20  1995Q3
# 21  1995Q4
# 22  1996Q1
# 23  1996Q2
# 24  1996Q3
# 25  1996Q4
# 26  1997Q1
# 27  1997Q2
# 28  1997Q3
# 29  1997Q4
# 30  1998Q1
# ⋮   ⋮
# 94  2014Q1
# 95  2014Q2
# 96  2014Q3
# 97  2014Q4
# 98  2015Q1
# 99  2015Q2
# 100 2015Q3
# 101 2015Q4
# 102 2016Q1
# 103 2016Q2
# 104 2016Q3
# 105 2016Q4
# 106 2017Q1
# 107 2017Q2
# 108 2017Q3
# 109 2017Q4
# 110 2018Q1
# 111 2018Q2
# 112 2018Q3
# 113 2018Q4
# 114 2019Q1
# 115 2019Q2
# 116 2019Q3
# 117 2019Q4
# 118 2020Q1
# 119 2020Q2
# 120 2020Q3
# 121 2020Q4
# 122 2021Q1
# 123 2021Q2
#     X       X.1     X.2
# 1   Male    Female  Total
# 2   1712100 1769500 3481500
# 3   1717300 1774200 3491500
# ...

# %%
Estimat_Resident_Population <- read.csv('migrant.csv')

# %%
Estimat_Resident_Population
# Out:
#    year
# 1  2005
# 2  2006
# 3  2007
# 4  2008
# 5  2009
# 6  2010
# 7  2011
# 8  2012
# 9  2013
# 10 2014
# 11 2015
# 12 2016
# 13 2017
# 14 2018
# 15 2019
# 16 2020
# 17 Table information:
# 18 Units:
# 19 Number, Magnitude = Units
# 20
# 21 Footnotes:
# 22 The standard error indicates the uncertainty of the provisional migration estimate. For example, the 95 percent confidence interval is +/-1.96 standard errors.
# 23 These intervals reflect the model uncertainty, not the extent of future revisions to provisional data. Standard errors are non-additive.
# 24 Owing to rounding, individual figures may not sum to stated totals.
# 25 Visa type is available from July 2003
# 26 The immigration visa type is that held or granted on arrival in New Zealand. People may change their visa type while still in New Zealand.
# 27
# 28 Symbols:
# 29 .. figure not available
# 30 C: Confidential
# 31 E: Early Estimate
# 32 P: Provisional
# 33 R: Revised
# 34 S: Suppressed
# 35
# ...
